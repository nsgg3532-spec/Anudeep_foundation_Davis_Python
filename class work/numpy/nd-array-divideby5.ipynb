# %% [markdown]
# <a href="https://colab.research.google.com/github/nsgg3532-spec/Anudeep_foundation_Davis_Python/blob/main/class%20work/numpy/nd-array-divideby5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
#to create arry
numbers= np.array([10,30,30,40])
print(numbers)
#dividing each element by 5
number2 = numbers/5
print("after divide by 5:")
print(number2)
# Out:
# [10 30 30 40]
# after divide by 5:
# [2. 6. 6. 8.]
