# %% [markdown]
# <a href="https://colab.research.google.com/github/nsgg3532-spec/Anudeep_foundation_Davis_Python/blob/main/self%20learning/list_conversion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = input("enter the input")
text = num.split()
part = list(map(int, text))
print(part)
# Out:
# enter the input1 2 3
# [1, 2, 3]
