# %% [markdown]
# <a href="https://colab.research.google.com/github/nsgg3532-spec/Anudeep_foundation_Davis_Python/blob/main/class%20work/numpy/int-to-float-nd-array.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
#to create arry
numbers= np.array([10,30.6,30,40])
print(numbers)
# Out:
# [10.  30.6 30.  40. ]
