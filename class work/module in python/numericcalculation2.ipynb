# %% [markdown]
# <a href="https://colab.research.google.com/github/nsgg3532-spec/Anudeep_foundation_Davis_Python/blob/main/class%20work/module%20in%20python/numericcalculation2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#function to add two number
def add(a, b):
    return a + b
#function to calculate differnce of two number
def sub(a, b):
    return (a - b)
#function to calculate pruduct of two number
def mul(a,b):
    return(a*b)
#function to calculate division
def dividenumber(a,b):
    return(a/b)
#function to calculate modulo
def calculatemodulo(a,b):
    return(a%b)
