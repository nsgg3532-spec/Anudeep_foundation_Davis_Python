# %% [markdown]
# <a href="https://colab.research.google.com/github/nsgg3532-spec/Anudeep_foundation_Davis_Python/blob/main/python_coding_challenge/check_ticket_price(q10).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 10 ticket price
def ticket():
    day = input("Enter day: ")
    if day.lower() == "sunday":
        print(200)
    else:
        print(150)
ticket()
# Out:
# Enter day: sunday
# 200
