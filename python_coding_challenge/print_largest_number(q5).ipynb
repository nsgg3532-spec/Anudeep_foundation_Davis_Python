# %% [markdown]
# <a href="https://colab.research.google.com/github/nsgg3532-spec/Anudeep_foundation_Davis_Python/blob/main/python_coding_challenge/print_largest_number(q5).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 5 print largest number
# a = int(input())
# b = int(input())
# c = int(input())
# print(max(a, b, c))
list = [10,25,15]
print(max(list))
# Out:
# 25
