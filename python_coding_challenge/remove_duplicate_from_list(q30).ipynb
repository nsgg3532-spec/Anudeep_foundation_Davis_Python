# %% [markdown]
# <a href="https://colab.research.google.com/github/nsgg3532-spec/Anudeep_foundation_Davis_Python/blob/main/python_coding_challenge/remove_duplicate_from_list(q30).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 31 remove duplicate from list
lst = [1,1,2,3]
print((set(lst)))
# Out:
# {1, 2, 3}
