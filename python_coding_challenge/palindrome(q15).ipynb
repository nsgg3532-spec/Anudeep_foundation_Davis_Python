# %% [markdown]
# <a href="https://colab.research.google.com/github/nsgg3532-spec/Anudeep_foundation_Davis_Python/blob/main/python_coding_challenge/palindrome(q15).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 15 palindrome number
def palindrome():
    n = input()
    if n == n[::-1]:
        print("Palindrome")
    else:
        print("Not Palindrome")

palindrome()
# Out:
# 121
# Palindrome
