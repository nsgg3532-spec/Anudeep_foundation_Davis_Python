# %% [markdown]
# <a href="https://colab.research.google.com/github/nsgg3532-spec/Anudeep_foundation_Davis_Python/blob/main/python_coding_challenge/count_numbers_of_greater_than_50(q13).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 13 print count numbers of greater than 50
lst = [10,60,30,80]
count = 0
for i in lst:
  if i > 50:
    count += 1
print(count)
# Out:
# 2
