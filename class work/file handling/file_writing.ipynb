# %% [markdown]
# <a href="https://colab.research.google.com/github/nsgg3532-spec/Anudeep_foundation_Davis_Python/blob/main/class%20work/file%20handling/file_writing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
filev = open("firstfile.txt", "w")
print("enter any five sentence :")
for x in range(5):
    #input data from user
    sentence = input()
    #writing sentence into file
    filev.write(sentence)
print("data succcessfully writen")
#closing the file
filev.close()
# Out:
# enter any five sentence :
