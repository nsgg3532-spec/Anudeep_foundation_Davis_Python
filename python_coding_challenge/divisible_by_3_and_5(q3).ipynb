# %% [markdown]
# <a href="https://colab.research.google.com/github/nsgg3532-spec/Anudeep_foundation_Davis_Python/blob/main/python_coding_challenge/divisible_by_3_and_5(q3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 3 divisible by 3 and 5
n = int(input("Enter number: "))
if n % 3 == 0 and n % 5 == 0:
        print("Yes")
else:
        print("No")
# Out:
# Enter number: 15
# Yes
