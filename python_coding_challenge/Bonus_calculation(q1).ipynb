# %% [markdown]
# <a href="https://colab.research.google.com/github/nsgg3532-spec/Anudeep_foundation_Davis_Python/blob/main/python_coding_challenge/Bonus_calculation(q1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Question 1: Bonus Calculation

def calculate_bonus(): # function to calculate bonus
    salary = int(input()) # taking input and store in salary
    bonus = salary * 0.07
    print("Bonus =", int(bonus))

calculate_bonus()
# Out:
# 45000
# Bonus = 3150
