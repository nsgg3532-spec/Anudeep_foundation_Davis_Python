# %% [markdown]
# <a href="https://colab.research.google.com/github/nsgg3532-spec/Anudeep_foundation_Davis_Python/blob/main/class%20work/numpy/textfile-fetch-from-github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

url = "https://raw.githubusercontent.com/nsgg3532-spec/Anudeep_foundation_Davis_Python/refs/heads/main/class%20work/file%20handling/file.txt"

response = requests.get(url)

lines = response.text.splitlines()

print("Total number of lines:", len(lines))
# Out:
# Total number of lines: 2
