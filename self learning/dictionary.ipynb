# %% [markdown]
# <a href="https://colab.research.google.com/github/nsgg3532-spec/Anudeep_foundation_Davis_Python/blob/main/self%20learning/dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student ={
    "name":"rahul singh",
    "age": 21
}
print(student.values())
print(student.keys())
print(student["name"])
student["college"]="AKTU"
print(student)
# Out:
# dict_values(['rahul singh', 21])
# dict_keys(['name', 'age'])
# rahul singh
# {'name': 'rahul singh', 'age': 21, 'college': 'AKTU'}
