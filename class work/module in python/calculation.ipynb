# %% [markdown]
# <a href="https://colab.research.google.com/github/nsgg3532-spec/Anudeep_foundation_Davis_Python/blob/main/class%20work/module%20in%20python/calculation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numericcalculation2
m= 10
n= 20
print("sum of :",m,"and",n,"is:",numericcalculation2.add(m,n))
print(m,n)
#print(numericcalculation2.add(5, 3))
#print(numericcalculation2.sub(10, 4))
