# %% [markdown]
# <a href="https://colab.research.google.com/github/nsgg3532-spec/Anudeep_foundation_Davis_Python/blob/main/python_coding_challenge/check_palindrome(madam)(q22).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 22 check palindrome
s = input()
if s == s[::-1]:
  print("Yes")
else:
  print("No")
# Out:
# madam
# Yes
