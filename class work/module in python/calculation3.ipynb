# %% [markdown]
# <a href="https://colab.research.google.com/github/nsgg3532-spec/Anudeep_foundation_Davis_Python/blob/main/class%20work/module%20in%20python/calculation3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numericcalculation2 import add
m = 10
n = 20
print("sum of ",m,"and",n,"is :",add(m,n))
print("product of ",m,"and",n,"is :",mul(m,n)) # this part is not exicuteable because function not imported
