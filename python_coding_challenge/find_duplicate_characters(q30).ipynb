# %% [markdown]
# <a href="https://colab.research.google.com/github/nsgg3532-spec/Anudeep_foundation_Davis_Python/blob/main/python_coding_challenge/find_duplicate_characters(q30).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 30 duplicate chars
def duplicate_chars():
    s = input()
    seen = set()
    dup = set()
    for c in s:
        if c in seen:
            dup.add(c)
        seen.add(c)
    print(*dup)
duplicate_chars()
# Out:
#  find duplicate characters.
# e c   r i d a t
